# %% [markdown]
# # Checkpoint Three: Cleaning Data
#
# Now you are ready to clean your data. Before starting coding, provide the link to your dataset below.
#
# My dataset: https://www.kaggle.com/datasets/thedevastator/higher-education-predictors-of-student-retention
#
# > Column category information can be found at https://www.mdpi.com/2306-5729/7/11/146 in Appendix A
#
# Import the necessary libraries and create your dataframe(s).

# %%
#Importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib import style
plt.style.use("seaborn-v0_8-bright")

# %%
#Creating dataframe
df = pd.read_csv("C:\\Users\\kap19\\OneDrive\\Desktop\\LaunchCode\\Codes\\Assignments\\Assignment 4 Final Project\\dataset.csv")

# %%
#Creating copy of dataframe for cleaning
df1= df.copy()

# %% [markdown]
# ## Missing Data
#
# Test your dataset for missing data and handle it as needed. Make notes in the form of code comments as to your thought process.

# %%
#Looking for missing data
sns.heatmap(df1.isnull(), cmap='viridis')
# Out:
# <Axes: >

# %%
#Second confirmation that no data is missing since above chart is not showing all columns
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Marital status - 0%
# Application mode - 0%
# Application order - 0%
# Course - 0%
# Daytime/evening attendance - 0%
# Previous qualification - 0%
# Nacionality - 0%
# Mother's qualification - 0%
# Father's qualification - 0%
# Mother's occupation - 0%
# Father's occupation - 0%
# Displaced - 0%
# Educational special needs - 0%
# Debtor - 0%
# Tuition fees up to date - 0%
# Gender - 0%
# Scholarship holder - 0%
# Age at enrollment - 0%
# International - 0%
# Curricular units 1st sem (credited) - 0%
# Curricular units 1st sem (enrolled) - 0%
# Curricular units 1st sem (evaluations) - 0%
# Curricular units 1st sem (approved) - 0%
# Curricular units 1st sem (grade) - 0%
# Curricular units 1st sem (without evaluations) - 0%
# Curricular units 2nd sem (credited) - 0%
# Curricular units 2nd sem (enrolled) - 0%
# Curricular units 2nd sem (evaluations) - 0%
# Curricular units 2nd sem (approved) - 0%
# Curricular units 2nd sem (grade) - 0%
# ...

# %% [markdown]
# ## Irregular Data
#
# Detect outliers in your dataset and handle them as needed. Use code comments to make notes about your thought process.

# %%
#Checking if inflation rate column as an outliers
df1['Inflation rate'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
#Checking if unemploymemt rate column as an outliers
df1['Unemployment rate'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
#Checking if GDP column as an outliers
df1['GDP'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
#Determining of Course values has an outliers
df1['Course'].value_counts().plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# ## Unnecessary Data
#
# Look for the different types of unnecessary data in your dataset and address it as needed. Make sure to use code comments to illustrate your thought process.

# %%
#Dropping all of the Curriculum columns- they don't really have an understandable meaning to the data and/or similar info can be found in another column
df2= df1.drop(columns=["Curricular units 1st sem (credited)", "Curricular units 1st sem (enrolled)", "Curricular units 1st sem (evaluations)", "Curricular units 1st sem (approved)", "Curricular units 1st sem (grade)", "Curricular units 1st sem (without evaluations)", "Curricular units 2nd sem (credited)", "Curricular units 2nd sem (enrolled)", "Curricular units 2nd sem (evaluations)", "Curricular units 2nd sem (approved)", "Curricular units 2nd sem (grade)", "Curricular units 2nd sem (without evaluations)"])
df2
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                 8                  5       2
# 1                  1                 6                  1      11
# 2                  1                 1                  5       5
# 3                  1                 8                  2      15
# 4                  2                12                  1       3
# ...              ...               ...                ...     ...
# 4419               1                 1                  6      15
# 4420               1                 1                  2      15
# 4421               1                 1                  1      12
# 4422               1                 1                  1       9
# 4423               1                 5                  1      15
#
#       Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                              1                       1            1
# ...

# %%
#Checking for duplicate data
df2.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4419    False
# 4420    False
# 4421    False
# 4422    False
# 4423    False
# Length: 4424, dtype: bool

# %% [markdown]
# ## Inconsistent Data
#
# Check for inconsistent data and address any that arises. As always, use code comments to illustrate your thought process.

# %%
#Not inconsistent data but updating Nationality column to correct spelling mistake
df2.rename(columns={"Nacionality": "Nationality"})
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                 8                  5       2
# 1                  1                 6                  1      11
# 2                  1                 1                  5       5
# 3                  1                 8                  2      15
# 4                  2                12                  1       3
# ...              ...               ...                ...     ...
# 4419               1                 1                  6      15
# 4420               1                 1                  2      15
# 4421               1                 1                  1      12
# 4422               1                 1                  1       9
# 4423               1                 5                  1      15
#
#       Daytime/evening attendance  Previous qualification  Nationality  \
# 0                              1                       1            1
# ...

# %%
#Exporting clean dataset
df2.to_csv("C:\\Users\\kap19\\OneDrive\\Desktop\\LaunchCode\\Codes\\Assignments\\Assignment 4 Final Project\\dataset.csv")

# %% [markdown]
# ## Summarize Your Results
#
# Make note of your answers to the following questions.
#
# 1. Did you find all four types of dirty data in your dataset?
# >The only type of dirty data that I found in this data set was unnecessary data. I felt that the Curriculum columns were not clear for its data and similar data could be found in the course column. There was no missing data, irregular data or inconsistent data that I could determine in the data set.
# 2. Did the process of cleaning your data give you new insights into your dataset?
# >The process of cleaning my data allowed me to better view the columns within the data set and the distribution of values in a few of the columns.
# 3. Is there anything you would like to make note of when it comes to manipulating the data and making visualizations?
# >I would like to view more about the inflation, unemployment rate, GDP and course data and how it correlates with the target column.
